# %%
import base64
import requests as rq
import json
import pandas as pd

# %%
# Define a function in order to obtain our personalised token

def get_oauth_token():
    '''
    This function will return our personalised token
    '''
    api_key = 'fmsbh2n7x8fp28gv1zjz994y7zcb349h'   # Your API key provided by Idealista
    secret = 'Cv6xmEfeYMSL'   # Your secred code provided by Idealista

    message = api_key + ":" + secret   # Combine the API key and the secret to get our personalised message

    auth = "Basic " + base64.b64encode(message.encode("ascii")).decode("ascii")   # Encode the message

    headers_dic = {"Authorization" : auth,
                   "Content-Type" : "application/x-www-form-urlencoded;charset=UTF-8"}   # Define our headers

    params_dic = {"grant_type" : "client_credentials",   # Define the request params
                  "scope" : "read"}

    r = rq.post("https://api.idealista.com/oauth/token",   # Perform the request with the api url, headers and params
                      headers = headers_dic,
                      params = params_dic)

    token = json.loads(r.text)['access_token']   # Obtain the personalised token, as a json

    return token

# %%
# This are the params we will use to filter our search

base_url = 'https://api.idealista.com/3.5/'     # Base search url
country = 'es'     # Search country (es, it, pt)
language = 'es'     # Search language (es, it, pt, en, ca)
max_items = '50'     # Max items per call, the maximum set by Idealista is 50
operation = 'sale'     # Kind of operation (sale, rent)
property_type = 'homes'     # Type of property (homes, offices, premises, garages, bedrooms)
order = 'distance'     # Order of the listings, consult documentation for all the available orders
center = '37.391285,-5.962270'     # Coordinates of the search center
distance = '60000'     # Max distance from the center
sort = 'asc'     # How to sort the found items
bankOffer = 'false'     # If the owner is a bank
# maxprice = '750'     # Max price of the listings

# %%
# Define a function to obtain our search url

def define_search_url():
    '''
    This function will combine our params with the url, in order to create our own search url
    '''
    url = (base_url +
           country +
           '/search?operation=' + operation +
           '&maxItems=' + max_items +
           '&order=' + order +
           '&center=' + center +
           '&distance=' + distance +
           '&propertyType=' + property_type +
           '&sort=' + sort +
           '&numPage=%s' +
           # '&maxPrice=' + maxprice +
           '&language=' + language)

    return url

# %%
url = define_search_url()
url
# Out:
# 'https://api.idealista.com/3.5/es/search?operation=sale&maxItems=50&order=distance&center=37.391285,-5.962270&distance=60000&propertyType=homes&sort=asc&numPage=%s&language=es'

# %%
def search_api(url):
    '''
    This function will use the token and url created previously, and return our search results.
    '''
    token = get_oauth_token()   #  Get the personalised token

    headers = {'Content-Type': 'Content-Type: multipart/form-data;',   # Define the search headers
               'Authorization' : 'Bearer ' + token}

    content = rq.post(url, headers = headers)   # Return the content from the request

    result = json.loads(content.text)   # Transform the result as a json file

    return result

# %%
# Since we need to give pagination to our search and this is our first search, we will set the pagination as 1
pagination = 1
first_search_url = url %(pagination)

# %%
# Proceed to do the search with the paginated url
results = search_api(first_search_url)

# %%
results
# Out:
# {'elementList': [{'propertyCode': '104379438',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/c6/05/c5/1218705239.jpg',
#    'numPhotos': 14,
#    'floor': '1',
#    'price': 114000.0,
#    'priceInfo': {'price': {'amount': 114000.0,
#      'priceDropInfo': {'formerPrice': 119000.0,
#       'priceDropValue': 5000,
#       'priceDropPercentage': 4}}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 90.0,
#    'exterior': True,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'calle Memphis',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'San Pablo',
#    'country': 'es',
#    'neighborhood': 'San Pablo',
#    'latitude': 37.3913318,
#    'longitude': -5.9622749,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/104379438/',
#    'distance': '5',
#    'description': '¡OPORTUNIDAD! Se vende piso en calle Memphis. El piso es un primero, el cual consta de 90m2 distribuidos en 2 dormitorios (antes 3), cocina, baño y salón con terraza incorporada. El segundo dormitorio está actualmente como vestidor y para poder acceder a él hay que pasar por el dormitorio principal. Zona San Pablo, barrio C. Ubicado en una zona con buena comunicación mediante transporte público y rodeada de centros educativos, centros de salud y supermercados. Ideal para parejas jóvenes y mayores, familias numerosas e inversores. ¡1ª planta sin ascensor! 114.000€ ¿Necesita hipoteca o financiación? También contamos con el departamento financiero. Desde inmobiliaria Inmofirma nos encargamos de todas las gestiones necesarias para llevar a cabo la compraventa de su vivienda de la mejor manera posible.   ¡Llame, pregunte y visítelo sin ningún tipo de compromiso! Te informaremos sobre la vivienda y sobre todos los gastos de compraventa.',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 1267.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Pablo, Sevilla',
#     'title': 'Piso en calle Memphis'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104577954',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/05/ec/30/1224944926.jpg',
#    'numPhotos': 24,
#    'floor': '4',
#    'price': 95000.0,
#    'priceInfo': {'price': {'amount': 95000.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 67.0,
#    'exterior': True,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'barrio San Pablo',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'San Pablo',
#    'country': 'es',
#    'neighborhood': 'San Pablo',
#    'latitude': 37.3931316,
#    'longitude': -5.9631649,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/104577954/',
#    'distance': '220',
#    'description': '¡No pierdas la oportunidad de adquirir este magnífico piso completamente reformado en San Pablo B! Con una superficie de 67m² y ubicado en la cuarta planta sin ascensor, cuenta con dos dormitorios, un baño completo y un amplio salón comedor. Además, la cocina independiente y completamente amueblada te permitirá cocinar cómodamente en tu nuevo hogar. Dispone de trastero. Disfruta de de vivir en una zona con todos los servicios necesarios a tu alcance, como comercios, supermercados y colegios cercanos. Además, la buena comunicación en transporte público te permitirá moverte por la ciudad con facilidad. Precio de venta no incluye impuestos, gastos de compraventa, notariales, registrales, honorarios de agencia ni gestión hipotecaria. ¡Te esperamos!',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 1418.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Pablo, Sevilla', 'title': 'Piso'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Destacado'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104088494',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/9c/39/26/1209406485.jpg',
#    'numPhotos': 23,
#    'floor': '12',
#    'price': 187000.0,
#    'priceInfo': {'price': {'amount': 187000.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 125.0,
#    'exterior': True,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'avenida de la Solea',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'San Pablo',
#    'country': 'es',
#    'neighborhood': 'San Pablo',
#    'latitude': 37.39222,
#    'longitude': -5.964959,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/104088494/',
#    'distance': '259',
#    'description': '¡Increíble oportunidad de vivienda en el Barrio de San Pablo! Este luminoso piso de 125m² en la planta 12 te ofrece unas vistas espectaculares y una ubicación inmejorable.  Con 3 dormitorios, 2 baños, cocina, salón comedor y mucha luz natural, es el hogar ideal para tu familia.  Además, cuenta con servicios cercanos, como supermercados, farmacias y transporte público. A tan solo 10 minutos del centro de Sevilla en autobús, ¡no dejes pasar esta oportunidad!  Honorarios de agencia del 3%. ¡Contacta con nosotros ya!',
#    'hasVideo': True,
#    'status': 'renew',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1496.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Pablo, Sevilla',
#     'title': 'Piso en avenida de la Solea'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104583410',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/3d/f8/d5/1225145155.jpg',
#    'externalReference': 'V-SPA-513',
#    'numPhotos': 25,
#    'floor': '1',
#    'price': 99995.0,
#    'priceInfo': {'price': {'amount': 99995.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 53.0,
#    'exterior': True,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'barrio San Pablo',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'San Pablo',
#    'country': 'es',
#    'neighborhood': 'San Pablo',
#    'latitude': 37.3924503,
#    'longitude': -5.965462,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/104583410/',
#    'distance': '310',
#    'description': 'Piso en San Pablo barrio A en primera planta sin ascensor, distribuidos en salón-comedor, cocina independiente, 2 dormitorios dobles, y un baño. Llama para reservar tu plaza en el DIRECTO que tendremos en los próximos días para que puedas tener la OPORTUNIDAD de ver en exclusiva la presentación en streaming de esta magnifica vivienda (plazas limitadas). Para finalizar nos gustaría informar a los clientes que los honorarios a percibir por RGMFincas Inmobiliaria serán del 4%+IVA (mínimo 6.655€ con IVA incluido). Los gastos de notaría, gestoría, impuesto de transmisiones patrimoniales y registro no están incluidos en el precio.',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 1887.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Pablo, Sevilla', 'title': 'Piso'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Top'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '103550397',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/05/82/b3/1193044319.jpg',
#    'externalReference': 'CAN0000197397',
#    'numPhotos': 25,
#    'floor': '2',
#    'price': 270000.0,
#    'priceInfo': {'price': {'amount': 270000.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 91.0,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'avenida de Andalucía',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Gran Plaza - Marqués de Pickman - Ciudad Jardín',
#    'latitude': 37.3886822,
#    'longitude': -5.9609673,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/103550397/',
#    'distance': '311',
#    'description': 'Os presentamos este piso situado en Sevilla. La vivienda se distribuye en dos habitaciones, salón-comedor, cocina, un baño y un balcón. Situado en la 2a planta del edificio. Está situado en el centro de Sevilla. En sus alrededores encontramos el Hospital San Juan de Dios, escuelas, supermercados, bancos, bibliotecas, farmacias, oficinas de correos, varias paradas de autobús y la estación de metro 1º de Mayo. En términos de accesibilidad, la propiedad dispone de múltiples conexiones y cuenta con fácil acceso a A-92. En Aliseda Inmobiliaria tenemos la mayor oferta de inmuebles al mejor precio garantizado. Descubre nuestra amplia oferta inmobiliaria y no pierdas la oportunidad de encontrar la casa perfecta para ti.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 2967.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Gran Plaza - Marqués de Pickman - Ciudad Jardín, Sevilla',
#     'title': 'Piso en avenida de Andalucía'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': True,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Destacado'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '102916820',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/26/e3/69/1213447926.jpg',
#    'externalReference': 'CS-19198-0001',
#    'numPhotos': 1,
#    'floor': '3',
#    'price': 44900.0,
#    'priceInfo': {'price': {'amount': 44900.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 54.0,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'barrio San Pablo',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'San Pablo',
#    'country': 'es',
#    'neighborhood': 'San Pablo',
#    'latitude': 37.3941273,
#    'longitude': -5.9635706,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/102916820/',
#    'distance': '336',
#    'description': 'Vivienda piso situado en un edificio residencial en la ciudad de Sevilla.',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 831.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Pablo, Sevilla', 'title': 'Piso'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104717854',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/1e/fb/34/1229540822.jpg',
#    'externalReference': 'San Pablo',
#    'numPhotos': 8,
#    'floor': 'en',
#    'price': 95000.0,
#    'priceInfo': {'price': {'amount': 95000.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 65.0,
#    'exterior': True,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'barrio San Pablo',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'San Pablo',
#    'country': 'es',
#    'neighborhood': 'San Pablo',
#    'latitude': 37.3936418,
#    'longitude': -5.9646666,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/104717854/',
#    'distance': '336',
#    'description': 'Se vende piso en San Pablo en PLANTA BAJA, próximo a centro comercial Los Arcos y a 5 minutos de la estación de Santa Justa. La vivienda cuenta con 65 m2 distribuidos de la siguiente forma: Salón comedor con A/A, dos habitaciones (antes 3), un cuarto de baño con placa de ducha y una amplia cocina. Muy luminoso y en buen estado. Con todo tipo de comercios y servicios a su alcance, parque infantil, supermercados, comercios de barrio, etc. ¡VISITELO!',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 1462.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Pablo, Sevilla', 'title': 'Piso'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104669506',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/62/77/38/1227998677.jpg',
#    'externalReference': 'manuel-22041',
#    'numPhotos': 13,
#    'floor': '3',
#    'price': 128000.0,
#    'priceInfo': {'price': {'amount': 128000.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 77.0,
#    'exterior': True,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'calle Bizancio',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'San Pablo',
#    'country': 'es',
#    'neighborhood': 'San Pablo',
#    'latitude': 37.3933257,
#    'longitude': -5.9591245,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/104669506/',
#    'distance': '358',
#    'description': 'CREDIT HOME SEVILLA REAL ESTATE ofrece PISO en San Pablo, Sevilla. El inmueble cuenta con 76 metros cuadrados construidos, distribuidos en dos amplias habitaciones, baño completo, cocina independiente y salón.  El piso está de orígen, pero muy cuidado. Ubicado cerca del La Avenida de Kansas City a escasos metros de La Estación de Santa Justa. Rodeada de comercios, bares, clínicas, restaurantes, colegios, etc.. . Es lo que estás buscando? No dudes en visitarla, le atendemos sin compromiso! Le atendemos también por WhatsApp. En CREDIT HOME SEVILLA REAL ESTATE, trabajamos para ofrecer a nuestros clientes su vivienda soñada. Cubrimos todas las necesidades demandadas: casas, pisos, locales, terrenos, oficinas, etc. y ofrecemos a nuestros clientes asesoramiento inmobiliario y financiero. Si necesitas financiación, nuestra oficina cuenta con profesionales en el área que te brindarán seguridad, rentabilidad y la mejor oferta del mercado. Honorarios de intermediación inmobiliaria no incluidos en el precio, no están incluidos los gastos propios de la compraventa. Documento D. I. A. a disposición del consumidor según Decreto 218/2005 Junta de Andalucía. " ¡Solicítenos más información sin compromiso!',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1662.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Pablo, Sevilla',
#     'title': 'Piso en calle Bizancio'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Destacado'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104455365',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/7b/0f/53/1221285538.jpg',
#    'numPhotos': 21,
#    'floor': '2',
#    'price': 107000.0,
#    'priceInfo': {'price': {'amount': 107000.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 75.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'calle Hebrón',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'San Pablo',
#    'country': 'es',
#    'neighborhood': 'San Pablo',
#    'latitude': 37.3940569,
#    'longitude': -5.9600355,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/104455365/',
#    'distance': '365',
#    'description': 'Vivienda en San Pablo ( Barrio C )  ¡ ASCENSOR PAGADO, EN PROCESO DE OBRA INMINENTE! Negociable!   Piso de 3 habitaciones en Barrio C de SAN PABLO Características: - 3 Dormitorios. - 1 Baño, grande con bañera. - Salón-comedor. - Terraza. - Cocina. - Aire Acondicionado "Split" de frio - calor. En salón y habitación principal. "Inverter" (bajo consumo energético). - Electricidad actualizada. - 65 metros útiles. - Paredes de gota, suelos de terrazo, ventanas de aluminio lacado blanco, persianas habitaciones nuevas.. . - 30 € de Comunidad. - Gas Natural. Si necesitas asesoramiento financiero es Gratuito! Honorarios por la intermediación inmobiliaria de 3.000€ + IVA.',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 1427.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Pablo, Sevilla',
#     'title': 'Piso en calle Hebrón'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '103772430',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/c6/7d/dc/1200808811.jpg',
#    'externalReference': '1B4101168',
#    'numPhotos': 24,
#    'floor': '1',
#    'price': 248000.0,
#    'priceInfo': {'price': {'amount': 248000.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 67.0,
#    'exterior': True,
#    'rooms': 2,
#    'bathrooms': 2,
#    'address': 'calle Santa Elena',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Nervión',
#    'latitude': 37.388416,
#    'longitude': -5.964594,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/103772430/',
#    'distance': '379',
#    'description': 'VIVIENDA 2 dormitorios EN NERVIÓN.   Muy bien ubicada en zona calle Beatriz de Suabia a la altura de Luis Montoto.   Todos los servicios a pie de calle (supermercados, farmacias, colegios, restaurantes) y bien comunicada mediante paradas de autobuses, parada de metro y el próximo año conexión de tranvía al centro histórico.   Vivienda en planta primera, el piso esta distribuido con salón-comedor con cocina independiente y 2 baños; 2 dormitorios, el dormitorio principal tipo suit con baño incorporado, armarios empotrados.     Calidades: Máximo nivel de calidades, ventanas PVC con doble acristalamiento tipo Climalit de primeras marcas en sanitarios, suelo de madera y en solería de azulejos en baño. Aire acondicionado frio/calor y agua caliente por Aerotermia.   OPCIONAL: Vivienda + plaza de garaje nº 1 + trastero nº 1 = 272.000 €   El precio indicado incluye los honorarios por servicios de intermediación inmobiliaria, no se incluyen los gastos de notaría, registro y gestoría ni los tributos que puedan corresponderle al comprador/a.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': False,
#     'parkingSpacePrice': 30000.0},
#    'priceByArea': 3701.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Nervión, Sevilla',
#     'title': 'Piso en calle Santa Elena'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Destacado'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '103792876',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/29/e5/4c/1200347150.jpg',
#    'numPhotos': 99,
#    'price': 710000.0,
#    'priceInfo': {'price': {'amount': 710000.0}},
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 207.0,
#    'rooms': 4,
#    'bathrooms': 4,
#    'address': 'calle María Josefa Segovia',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Luis Montoto - Santa Justa',
#    'latitude': 37.3892902,
#    'longitude': -5.9658046,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/103792876/',
#    'distance': '383',
#    'description': 'Fantástico chalet adosado reformado de 4 habitaciones y 3 baños y 1 aseo en Huertas de Santa Teresa, Sevilla. El inmueble se encuentra en un magnífico estado y con orientación sur. Está ubicado en un barrio de chalets adosados muy tranquilo y con todo tipo recursos aun paso del inmueble.  El Chalet cuenta por tanto con 4 habitaciones, 3 baños, 1 aseo, 1 trastero, 2 patios ( uno de entrada y otro en la parte de atrás). Una de las características a destacar es que dispone de calefacción y aire acondicionado centralizado dando servicio a todas las estancias, garantizando una agradable temperatura en cualquier época del año.  En cuanto a las características interiores del chalet, podemos comenzar con su distribución: -En la planta baja dispone de entrada de puerta de garaje para vehículos pequeños ( coche smart, motos, etc ), también dispone de entrada que da paso al hall distribuidor, dejando a la derecha un aseo, al frente la escalera que da acceso a las plantas superiores y la puerta de la moderna y amplia cocina con acceso directo a la terraza, por último y a la izquierda de la cocina, un gran salón comedor muy luminoso con una gran cierro acristalado que da mucha luminosidad y confort. -En la primera planta dispone de distribuidor, dando paso a un cuarto de baño completo, un office lavadero con zona de planchado, dos dormitorios individuales con armarios empotrados y al amplio dormitorio principal de matrimonio con cuarto de baño privado y vestidor luminoso con doble acceso desde vestidor y dormitorio a un gran balcón, siendo todas las estancias muy luminosas y confortables.  -En la segunda planta, se encuentra un trastero con con acceso directo desde el distribuido, puerta de acceso a la gran terraza ático y a un gran dormitorio de matrimonio con cuarto de baño completo privado y terraza. ¡No deje pasar esta oportunidad única! Venga a visitar este maravilloso chalet adosado en Huertas de Santa Teresa, Sevilla y descubra cómo puede ser su nuevo hogar. ¡Contáctanos ahora mismo para concertar una visita! ¡No esperes más para vivir la vida que siempre has deseado en Sevilla! Por expreso deseo del propietario, este inmueble lo comercializa en EXCLUSIVA VK Inmobiliaria. Por este motivo, se ruega no molestar al propietario, a los ocupantes de la propiedad y/o a los vecinos. Nuestros asesores le facilitarán toda la información que precise. ¿ Quiere saber más? Estamos encantados de ayudarle a elegir el mejor hogar para su familia. Para más información, gustosamente le atenderemos en nuestras oficinas de VK Inmobiliaria en Nervión y VK inmobiliaria en los Remedios, situadas en Avenida San Francisco Javier nº7 y Calle asunción nº23.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 3430.0,
#    'detailedType': {'typology': 'chalet', 'subTypology': 'terracedHouse'},
#    'suggestedTexts': {'subtitle': 'Luis Montoto - Santa Justa, Sevilla',
#     'title': 'Chalet adosado en calle María Josefa Segovia'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': True,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Top'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104470837',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/55/a6/ca/1221639707.jpg',
#    'externalReference': '100096672',
#    'numPhotos': 20,
#    'floor': '12',
#    'price': 396000.0,
#    'priceInfo': {'price': {'amount': 396000.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 124.0,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Calle Rojas Zorrilla',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Luis Montoto - Santa Justa',
#    'latitude': 37.3899969,
#    'longitude': -5.9663188,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/obra-nueva/104470837/',
#    'distance': '385',
#    'description': 'TORREMAGNA. Obra nueva plurifamiliar de 91 viviendas con plazas de garajes y trasteros. Viviendas de 2, 3 y 4 dormitorios, con tipologías con estancias plus, pensada para atender todas tus necesidades (despacho, zona de teletrabajo, vestidor, zona de juegos). Nuevo lanzamiento comercial en La Cruz del Campo, en nuevo sector en desarrollo, en pleno centro geográfico de Sevilla, con todas las comodidades y servicios. Disfrute de una nueva forma de vivir junto a Nervión, en un entorno tranquilo, y con rápidas comunicaciones. El edificio está desarrollado en planta baja más doce alturas, disponiéndose en forma de L abierto al suroeste, para favorecer el soleamiento y la orientación de las viviendas, cuenta con amplios espacios y dotaciones comunitarias de piscina, local comunitario, área de juegos infantiles y una plaza elevada de disfrute exclusivo.  Las viviendas están configuradas con doble fachada en la mayoría de las tipologías, favoreciendo la ventilación cruzada y el soleamiento por sus orientaciones. Cuenta con grandes terrazas, y jardines de uso privativo en planta baja, para permitirle vivir como siempre ha soñado. Cocinas amuebladas incluidas, y posibilidad de personalización de su vivienda. Diseñado con los estándares de calidad y sostenibilidad propios de Metrovacesa, con el valor añadido de certificación sostenible con Sello Verde (GBCe), y Domum de Metrovacesa. Bajo rasante se sitúan dos sótanos donde se ubican las plazas de aparcamiento y los trasteros, con acceso directo desde los portales. También cuenta con aparcamiento para bicicletas en urbanización. Las viviendas se venden de manera conjunta con una plaza de garaje y un trastero con precios desde 28.000€ y 4.000€ respectivamente. Promoción en Fase de Comercialización. Es tu vida, elige dónde vivirla.',
#    'hasVideo': False,
#    'status': 'newdevelopment',
#    'newDevelopment': True,
#    'hasLift': True,
#    'newDevelopmentFinished': False,
#    'priceByArea': 3194.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Luis Montoto - Santa Justa, Sevilla',
#     'title': 'Piso en Calle Rojas Zorrilla'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Top'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104470805',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/31/ca/70/1221639545.jpg',
#    'externalReference': '100096584',
#    'numPhotos': 20,
#    'price': 341500.0,
#    'priceInfo': {'price': {'amount': 341500.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 112.0,
#    'rooms': 2,
#    'bathrooms': 2,
#    'address': 'Calle Rojas Zorrilla',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Luis Montoto - Santa Justa',
#    'latitude': 37.3899969,
#    'longitude': -5.9663188,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/obra-nueva/104470805/',
#    'distance': '385',
#    'description': 'TORREMAGNA. Obra nueva plurifamiliar de 91 viviendas con plazas de garajes y trasteros. Viviendas de 2, 3 y 4 dormitorios, con tipologías con estancias plus, pensada para atender todas tus necesidades (despacho, zona de teletrabajo, vestidor, zona de juegos). Nuevo lanzamiento comercial en La Cruz del Campo, en nuevo sector en desarrollo, en pleno centro geográfico de Sevilla, con todas las comodidades y servicios. Disfrute de una nueva forma de vivir junto a Nervión, en un entorno tranquilo, y con rápidas comunicaciones. El edificio está desarrollado en planta baja más doce alturas, disponiéndose en forma de L abierto al suroeste, para favorecer el soleamiento y la orientación de las viviendas, cuenta con amplios espacios y dotaciones comunitarias de piscina, local comunitario, área de juegos infantiles y una plaza elevada de disfrute exclusivo.  Las viviendas están configuradas con doble fachada en la mayoría de las tipologías, favoreciendo la ventilación cruzada y el soleamiento por sus orientaciones. Cuenta con grandes terrazas, y jardines de uso privativo en planta baja, para permitirle vivir como siempre ha soñado. Cocinas amuebladas incluidas, y posibilidad de personalización de su vivienda. Diseñado con los estándares de calidad y sostenibilidad propios de Metrovacesa, con el valor añadido de certificación sostenible con Sello Verde (GBCe), y Domum de Metrovacesa. Bajo rasante se sitúan dos sótanos donde se ubican las plazas de aparcamiento y los trasteros, con acceso directo desde los portales. También cuenta con aparcamiento para bicicletas en urbanización. Las viviendas se venden de manera conjunta con una plaza de garaje y un trastero con precios desde 28.000€ y 4.000€ respectivamente. Promoción en Fase de Comercialización. Es tu vida, elige dónde vivirla.',
#    'hasVideo': False,
#    'status': 'newdevelopment',
#    'newDevelopment': True,
#    'hasLift': True,
#    'newDevelopmentFinished': False,
#    'priceByArea': 3049.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Luis Montoto - Santa Justa, Sevilla',
#     'title': 'Piso en Calle Rojas Zorrilla'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Top'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104470820',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/b4/4e/68/1221639574.jpg',
#    'externalReference': '100096588',
#    'numPhotos': 20,
#    'price': 418000.0,
#    'priceInfo': {'price': {'amount': 418000.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 140.0,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Calle Rojas Zorrilla',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Luis Montoto - Santa Justa',
#    'latitude': 37.3899969,
#    'longitude': -5.9663188,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/obra-nueva/104470820/',
#    'distance': '385',
#    'description': 'TORREMAGNA. Obra nueva plurifamiliar de 91 viviendas con plazas de garajes y trasteros. Viviendas de 2, 3 y 4 dormitorios, con tipologías con estancias plus, pensada para atender todas tus necesidades (despacho, zona de teletrabajo, vestidor, zona de juegos). Nuevo lanzamiento comercial en La Cruz del Campo, en nuevo sector en desarrollo, en pleno centro geográfico de Sevilla, con todas las comodidades y servicios. Disfrute de una nueva forma de vivir junto a Nervión, en un entorno tranquilo, y con rápidas comunicaciones. El edificio está desarrollado en planta baja más doce alturas, disponiéndose en forma de L abierto al suroeste, para favorecer el soleamiento y la orientación de las viviendas, cuenta con amplios espacios y dotaciones comunitarias de piscina, local comunitario, área de juegos infantiles y una plaza elevada de disfrute exclusivo.  Las viviendas están configuradas con doble fachada en la mayoría de las tipologías, favoreciendo la ventilación cruzada y el soleamiento por sus orientaciones. Cuenta con grandes terrazas, y jardines de uso privativo en planta baja, para permitirle vivir como siempre ha soñado. Cocinas amuebladas incluidas, y posibilidad de personalización de su vivienda. Diseñado con los estándares de calidad y sostenibilidad propios de Metrovacesa, con el valor añadido de certificación sostenible con Sello Verde (GBCe), y Domum de Metrovacesa. Bajo rasante se sitúan dos sótanos donde se ubican las plazas de aparcamiento y los trasteros, con acceso directo desde los portales. También cuenta con aparcamiento para bicicletas en urbanización. Las viviendas se venden de manera conjunta con una plaza de garaje y un trastero con precios desde 28.000€ y 4.000€ respectivamente. Promoción en Fase de Comercialización. Es tu vida, elige dónde vivirla.',
#    'hasVideo': False,
#    'status': 'newdevelopment',
#    'newDevelopment': True,
#    'hasLift': True,
#    'newDevelopmentFinished': False,
#    'priceByArea': 2986.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Luis Montoto - Santa Justa, Sevilla',
#     'title': 'Piso en Calle Rojas Zorrilla'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Top'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104470836',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/8e/88/8f/1221639688.jpg',
#    'externalReference': '100096662',
#    'numPhotos': 20,
#    'floor': '10',
#    'price': 415000.0,
#    'priceInfo': {'price': {'amount': 415000.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 136.0,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Calle Rojas Zorrilla',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Luis Montoto - Santa Justa',
#    'latitude': 37.3899969,
#    'longitude': -5.9663188,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/obra-nueva/104470836/',
#    'distance': '385',
#    'description': 'TORREMAGNA. Obra nueva plurifamiliar de 91 viviendas con plazas de garajes y trasteros. Viviendas de 2, 3 y 4 dormitorios, con tipologías con estancias plus, pensada para atender todas tus necesidades (despacho, zona de teletrabajo, vestidor, zona de juegos). Nuevo lanzamiento comercial en La Cruz del Campo, en nuevo sector en desarrollo, en pleno centro geográfico de Sevilla, con todas las comodidades y servicios. Disfrute de una nueva forma de vivir junto a Nervión, en un entorno tranquilo, y con rápidas comunicaciones. El edificio está desarrollado en planta baja más doce alturas, disponiéndose en forma de L abierto al suroeste, para favorecer el soleamiento y la orientación de las viviendas, cuenta con amplios espacios y dotaciones comunitarias de piscina, local comunitario, área de juegos infantiles y una plaza elevada de disfrute exclusivo.  Las viviendas están configuradas con doble fachada en la mayoría de las tipologías, favoreciendo la ventilación cruzada y el soleamiento por sus orientaciones. Cuenta con grandes terrazas, y jardines de uso privativo en planta baja, para permitirle vivir como siempre ha soñado. Cocinas amuebladas incluidas, y posibilidad de personalización de su vivienda. Diseñado con los estándares de calidad y sostenibilidad propios de Metrovacesa, con el valor añadido de certificación sostenible con Sello Verde (GBCe), y Domum de Metrovacesa. Bajo rasante se sitúan dos sótanos donde se ubican las plazas de aparcamiento y los trasteros, con acceso directo desde los portales. También cuenta con aparcamiento para bicicletas en urbanización. Las viviendas se venden de manera conjunta con una plaza de garaje y un trastero con precios desde 28.000€ y 4.000€ respectivamente. Promoción en Fase de Comercialización. Es tu vida, elige dónde vivirla.',
#    'hasVideo': False,
#    'status': 'newdevelopment',
#    'newDevelopment': True,
#    'hasLift': True,
#    'newDevelopmentFinished': False,
#    'priceByArea': 3051.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Luis Montoto - Santa Justa, Sevilla',
#     'title': 'Piso en Calle Rojas Zorrilla'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104470824',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/56/d0/57/1221639650.jpg',
#    'externalReference': '100096646',
#    'numPhotos': 20,
#    'price': 397500.0,
#    'priceInfo': {'price': {'amount': 397500.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 136.0,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Calle Rojas Zorrilla',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Luis Montoto - Santa Justa',
#    'latitude': 37.3899969,
#    'longitude': -5.9663188,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/obra-nueva/104470824/',
#    'distance': '385',
#    'description': 'TORREMAGNA. Obra nueva plurifamiliar de 91 viviendas con plazas de garajes y trasteros. Viviendas de 2, 3 y 4 dormitorios, con tipologías con estancias plus, pensada para atender todas tus necesidades (despacho, zona de teletrabajo, vestidor, zona de juegos). Nuevo lanzamiento comercial en La Cruz del Campo, en nuevo sector en desarrollo, en pleno centro geográfico de Sevilla, con todas las comodidades y servicios. Disfrute de una nueva forma de vivir junto a Nervión, en un entorno tranquilo, y con rápidas comunicaciones. El edificio está desarrollado en planta baja más doce alturas, disponiéndose en forma de L abierto al suroeste, para favorecer el soleamiento y la orientación de las viviendas, cuenta con amplios espacios y dotaciones comunitarias de piscina, local comunitario, área de juegos infantiles y una plaza elevada de disfrute exclusivo.  Las viviendas están configuradas con doble fachada en la mayoría de las tipologías, favoreciendo la ventilación cruzada y el soleamiento por sus orientaciones. Cuenta con grandes terrazas, y jardines de uso privativo en planta baja, para permitirle vivir como siempre ha soñado. Cocinas amuebladas incluidas, y posibilidad de personalización de su vivienda. Diseñado con los estándares de calidad y sostenibilidad propios de Metrovacesa, con el valor añadido de certificación sostenible con Sello Verde (GBCe), y Domum de Metrovacesa. Bajo rasante se sitúan dos sótanos donde se ubican las plazas de aparcamiento y los trasteros, con acceso directo desde los portales. También cuenta con aparcamiento para bicicletas en urbanización. Las viviendas se venden de manera conjunta con una plaza de garaje y un trastero con precios desde 28.000€ y 4.000€ respectivamente. Promoción en Fase de Comercialización. Es tu vida, elige dónde vivirla.',
#    'hasVideo': False,
#    'status': 'newdevelopment',
#    'newDevelopment': True,
#    'hasLift': True,
#    'newDevelopmentFinished': False,
#    'priceByArea': 2923.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Luis Montoto - Santa Justa, Sevilla',
#     'title': 'Piso en Calle Rojas Zorrilla'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104470825',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/cc/6f/e0/1221639669.jpg',
#    'externalReference': '100096653',
#    'numPhotos': 20,
#    'price': 453500.0,
#    'priceInfo': {'price': {'amount': 453500.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 148.0,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Calle Rojas Zorrilla',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Luis Montoto - Santa Justa',
#    'latitude': 37.3899969,
#    'longitude': -5.9663188,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/obra-nueva/104470825/',
#    'distance': '385',
#    'description': 'TORREMAGNA. Obra nueva plurifamiliar de 91 viviendas con plazas de garajes y trasteros. Viviendas de 2, 3 y 4 dormitorios, con tipologías con estancias plus, pensada para atender todas tus necesidades (despacho, zona de teletrabajo, vestidor, zona de juegos). Nuevo lanzamiento comercial en La Cruz del Campo, en nuevo sector en desarrollo, en pleno centro geográfico de Sevilla, con todas las comodidades y servicios. Disfrute de una nueva forma de vivir junto a Nervión, en un entorno tranquilo, y con rápidas comunicaciones. El edificio está desarrollado en planta baja más doce alturas, disponiéndose en forma de L abierto al suroeste, para favorecer el soleamiento y la orientación de las viviendas, cuenta con amplios espacios y dotaciones comunitarias de piscina, local comunitario, área de juegos infantiles y una plaza elevada de disfrute exclusivo.  Las viviendas están configuradas con doble fachada en la mayoría de las tipologías, favoreciendo la ventilación cruzada y el soleamiento por sus orientaciones. Cuenta con grandes terrazas, y jardines de uso privativo en planta baja, para permitirle vivir como siempre ha soñado. Cocinas amuebladas incluidas, y posibilidad de personalización de su vivienda. Diseñado con los estándares de calidad y sostenibilidad propios de Metrovacesa, con el valor añadido de certificación sostenible con Sello Verde (GBCe), y Domum de Metrovacesa. Bajo rasante se sitúan dos sótanos donde se ubican las plazas de aparcamiento y los trasteros, con acceso directo desde los portales. También cuenta con aparcamiento para bicicletas en urbanización. Las viviendas se venden de manera conjunta con una plaza de garaje y un trastero con precios desde 28.000€ y 4.000€ respectivamente. Promoción en Fase de Comercialización. Es tu vida, elige dónde vivirla.',
#    'hasVideo': False,
#    'status': 'newdevelopment',
#    'newDevelopment': True,
#    'hasLift': True,
#    'newDevelopmentFinished': False,
#    'priceByArea': 3064.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Luis Montoto - Santa Justa, Sevilla',
#     'title': 'Piso en Calle Rojas Zorrilla'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104470822',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/fe/a6/e9/1221639612.jpg',
#    'externalReference': '100096637',
#    'numPhotos': 20,
#    'price': 439500.0,
#    'priceInfo': {'price': {'amount': 439500.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 148.0,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Calle Rojas Zorrilla',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Luis Montoto - Santa Justa',
#    'latitude': 37.3899969,
#    'longitude': -5.9663188,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/obra-nueva/104470822/',
#    'distance': '385',
#    'description': 'TORREMAGNA. Obra nueva plurifamiliar de 91 viviendas con plazas de garajes y trasteros. Viviendas de 2, 3 y 4 dormitorios, con tipologías con estancias plus, pensada para atender todas tus necesidades (despacho, zona de teletrabajo, vestidor, zona de juegos). Nuevo lanzamiento comercial en La Cruz del Campo, en nuevo sector en desarrollo, en pleno centro geográfico de Sevilla, con todas las comodidades y servicios. Disfrute de una nueva forma de vivir junto a Nervión, en un entorno tranquilo, y con rápidas comunicaciones. El edificio está desarrollado en planta baja más doce alturas, disponiéndose en forma de L abierto al suroeste, para favorecer el soleamiento y la orientación de las viviendas, cuenta con amplios espacios y dotaciones comunitarias de piscina, local comunitario, área de juegos infantiles y una plaza elevada de disfrute exclusivo.  Las viviendas están configuradas con doble fachada en la mayoría de las tipologías, favoreciendo la ventilación cruzada y el soleamiento por sus orientaciones. Cuenta con grandes terrazas, y jardines de uso privativo en planta baja, para permitirle vivir como siempre ha soñado. Cocinas amuebladas incluidas, y posibilidad de personalización de su vivienda. Diseñado con los estándares de calidad y sostenibilidad propios de Metrovacesa, con el valor añadido de certificación sostenible con Sello Verde (GBCe), y Domum de Metrovacesa. Bajo rasante se sitúan dos sótanos donde se ubican las plazas de aparcamiento y los trasteros, con acceso directo desde los portales. También cuenta con aparcamiento para bicicletas en urbanización. Las viviendas se venden de manera conjunta con una plaza de garaje y un trastero con precios desde 28.000€ y 4.000€ respectivamente. Promoción en Fase de Comercialización. Es tu vida, elige dónde vivirla.',
#    'hasVideo': False,
#    'status': 'newdevelopment',
#    'newDevelopment': True,
#    'hasLift': True,
#    'newDevelopmentFinished': False,
#    'priceByArea': 2970.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Luis Montoto - Santa Justa, Sevilla',
#     'title': 'Piso en Calle Rojas Zorrilla'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104470821',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/13/e9/74/1221639593.jpg',
#    'externalReference': '100096593',
#    'numPhotos': 20,
#    'price': 444500.0,
#    'priceInfo': {'price': {'amount': 444500.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 147.0,
#    'rooms': 4,
#    'bathrooms': 3,
#    'address': 'Calle Rojas Zorrilla',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Luis Montoto - Santa Justa',
#    'latitude': 37.3899969,
#    'longitude': -5.9663188,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/obra-nueva/104470821/',
#    'distance': '385',
#    'description': 'TORREMAGNA. Obra nueva plurifamiliar de 91 viviendas con plazas de garajes y trasteros. Viviendas de 2, 3 y 4 dormitorios, con tipologías con estancias plus, pensada para atender todas tus necesidades (despacho, zona de teletrabajo, vestidor, zona de juegos). Nuevo lanzamiento comercial en La Cruz del Campo, en nuevo sector en desarrollo, en pleno centro geográfico de Sevilla, con todas las comodidades y servicios. Disfrute de una nueva forma de vivir junto a Nervión, en un entorno tranquilo, y con rápidas comunicaciones. El edificio está desarrollado en planta baja más doce alturas, disponiéndose en forma de L abierto al suroeste, para favorecer el soleamiento y la orientación de las viviendas, cuenta con amplios espacios y dotaciones comunitarias de piscina, local comunitario, área de juegos infantiles y una plaza elevada de disfrute exclusivo.  Las viviendas están configuradas con doble fachada en la mayoría de las tipologías, favoreciendo la ventilación cruzada y el soleamiento por sus orientaciones. Cuenta con grandes terrazas, y jardines de uso privativo en planta baja, para permitirle vivir como siempre ha soñado. Cocinas amuebladas incluidas, y posibilidad de personalización de su vivienda. Diseñado con los estándares de calidad y sostenibilidad propios de Metrovacesa, con el valor añadido de certificación sostenible con Sello Verde (GBCe), y Domum de Metrovacesa. Bajo rasante se sitúan dos sótanos donde se ubican las plazas de aparcamiento y los trasteros, con acceso directo desde los portales. También cuenta con aparcamiento para bicicletas en urbanización. Las viviendas se venden de manera conjunta con una plaza de garaje y un trastero con precios desde 28.000€ y 4.000€ respectivamente. Promoción en Fase de Comercialización. Es tu vida, elige dónde vivirla.',
#    'hasVideo': False,
#    'status': 'newdevelopment',
#    'newDevelopment': True,
#    'hasLift': True,
#    'newDevelopmentFinished': False,
#    'priceByArea': 3024.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Luis Montoto - Santa Justa, Sevilla',
#     'title': 'Piso en Calle Rojas Zorrilla'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104718792',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/93/2e/93/1229576716.jpg',
#    'numPhotos': 16,
#    'floor': '2',
#    'price': 230000.0,
#    'priceInfo': {'price': {'amount': 230000.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 84.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'avenida de Andalucía',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Gran Plaza - Marqués de Pickman - Ciudad Jardín',
#    'latitude': 37.3881894,
#    'longitude': -5.9643139,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/104718792/',
#    'distance': '388',
# ...
#    'externalReference': 'AV.AND20',
#    'numPhotos': 23,
#    'floor': '2',
#    'price': 270000.0,
#    'priceInfo': {'price': {'amount': 270000.0,
#      'priceDropInfo': {'formerPrice': 284100.0,
#       'priceDropValue': 14100,
#       'priceDropPercentage': 5}}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 96.0,
#    'exterior': True,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'avenida de Andalucía, 20',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Gran Plaza - Marqués de Pickman - Ciudad Jardín',
#    'latitude': 37.3871913,
#    'longitude': -5.9599062,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/103912731/',
#    'distance': '500',
#    'description': 'Vivienda de dos dormitorios, salón comedor, baño, cocina y un amplio recibidor ubicada en la Avenida de Andalucía, frente al Centro Comercial Los Arcos. El piso ofrece buena iluminación y está equipado con cierres climalit y preinstalación de aire acondicionado. Además, dispone de una terraza en fachada con buenas vistas al exterior. La vivienda está situada en un edificio de 6 plantas con seguridad mediante cámaras de vigilancia, consta de piscina comunitaria y jardín comunitario. Ofrece la posibilidad de adquirir plaza de garaje y trastero existentes en el edificio. La vivienda necesita una pequeña reforma para conseguir la vivienda de tus sueños.  Enclavada en una zona de fácil acceso desde la SE-30 y rodeada de todos los servicios necesarios.  Producto procedente de banco. Honorarios de agencia incluidos en precio. Asesoramiento fiscal y estudio financiero. No lo dude y venga a visitarlo, le asesoramos en la gestión de compra y buscaremos la financiación que necesite. Impuestos y gastos de Notaría y registros no incluidos.',
#    'hasVideo': False,
#    'status': 'renew',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 2813.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Gran Plaza - Marqués de Pickman - Ciudad Jardín, Sevilla',
#     'title': 'Piso en avenida de Andalucía, 20'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '103619303',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/1f/e7/1b/1197045611.jpg',
#    'numPhotos': 82,
#    'floor': '2',
#    'price': 270000.0,
#    'priceInfo': {'price': {'amount': 270000.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 96.0,
#    'exterior': True,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'avenida de Andalucía, 20',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Gran Plaza - Marqués de Pickman - Ciudad Jardín',
#    'latitude': 37.3871913,
#    'longitude': -5.9599062,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/103619303/',
#    'distance': '500',
#    'description': 'Comercializamos una vivienda situada en la avenida de Andalucía 20, La vivienda se encuentra ubicado en un recinto cerrado, que cuenta con piscina y jardín. La vivienda consta de 96 metros cuadrados construidos, distribuidos en hall de entrada, cocina amueblada, salón comedor con salida a la terraza, 2 habitaciones y un cuarto de baño. El piso tiene armario empotrado en la habitación principal, preinstalación de aire acondicionado frio/calor, las ventanas son de climalit (doble acristalamiento). El cuarto de baño es amplio y cuenta con bañera. Esta vivienda tiene asignado el uso y disfrute de la planta cubierta del edificio. Se encuentra cercano a todo tipo de servicios, parques, comisaría de policía, entidades financieras, comercios de proximidad, centro comercial los arcos, farmacias, colegios, parada de bus y de taxi.. . La vivienda se ubica en una de las principales vías de acceso a la ciudad. Si desea ampliar información o concertar una visita, puede contactar con nosotros.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 2813.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Gran Plaza - Marqués de Pickman - Ciudad Jardín, Sevilla',
#     'title': 'Piso en avenida de Andalucía, 20'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104010645',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/b7/34/10/1207082746.jpg',
#    'numPhotos': 35,
#    'floor': '5',
#    'price': 249990.0,
#    'priceInfo': {'price': {'amount': 249990.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 163.0,
#    'exterior': True,
#    'rooms': 5,
#    'bathrooms': 2,
#    'address': 'barrio San Pablo',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'San Pablo',
#    'country': 'es',
#    'neighborhood': 'San Pablo',
#    'latitude': 37.3920663,
#    'longitude': -5.967869,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/104010645/',
#    'distance': '502',
#    'description': 'Magnífico piso situado en la zona de San Pablo. La vivienda cuenta con 163 metros construidos, tiene dos hall de entrada, a la izquierda se encuentra un dormitorio inspirado en vestidor, seguido de otro dormitorio principal y un cuarto de baño con placa ducha. A través del recibidor conecta con la cocina office con despensa, reformada en 2022 con suelo de porcelánico imitación madera, seguido de un cuarto de baño con bañera y dos dormitorios uno de ellos con armario empotrado. Dirigiéndonos por el pasillo nos encontramos a la izquierda otros 2 dormitorios, uno de ellos con armario empotrado, el amplio salón comedor y la terraza. Otras características: ventanas de climalit, la vivienda tiene 5 split individuales, situados uno en el salón y 4 en los dormitorios, tuberías y electricidad se arreglaron en el 2003, cerradura eléctrica y y azotea transitable. Comunidad muy cuidada, aparcamiento de moto y de bicis.  Este piso se encuentra cercano al Corte Ingles, centro comercial Mediamarkt, Mercadona, Nervión Plaza, y al barrio de santa clara y a pocos metros de la estación Santa Justa, fácil acceso a la SE30. Piso con muy buenas vistas y luminoso de grandes dimensiones perfecto para convertirlo en un gran hogar. Visítanos y te asesoramos sin compromiso. Ponemos a su disposición un asesor inmobiliario y financiero para informarle sobre los gastos de compraventa y de financiación. Estamos para ayudarle¡ ante cualquier duda o necesidad. ¡Visítenos sin compromiso!',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1534.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Pablo, Sevilla', 'title': 'Piso'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Destacado'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104670035',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/36/af/03/1228009655.jpg',
#    'externalReference': '492-6',
#    'numPhotos': 10,
#    'floor': '3',
#    'price': 455000.0,
#    'priceInfo': {'price': {'amount': 455000.0}},
#    'propertyType': 'duplex',
#    'operation': 'sale',
#    'size': 138.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'calle Padre Pedro Ayala, 12',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Gran Plaza - Marqués de Pickman - Ciudad Jardín',
#    'latitude': 37.3869415,
#    'longitude': -5.9639483,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/104670035/',
#    'distance': '505',
#    'description': 'Tercera planta exterior, tres dormitorios, dos baños (uno en suite) y gran terraza en planta ático. Nueva vivienda en construcción con opción de garaje y trasteros ubicada en pleno corazón de Nervión junto a la Cruz del Campo, Luis Montoto, El Corte Inglés, y al Centro Comercial Los Arcos. Entrega prevista para otoño de 2025. El edificio cuenta planta subterránea de aparcamientos y trasteros privados. Destaca su diseño moderno y elegante, con excelentes calidades. Cada vivienda está dotada de un equipamiento moderno, de calidad y tienen incluida la climatización con aerotermia, lo que reduce el consumo de energía, el aislamiento térmico y acústico en su interior, así como la instalación para las telecomunicaciones. Ventanas con doble cristal y con rotura de puente térmico. Puerta de entrada blindada, con cerradura de seguridad. Las puertas de paso en el interior de la vivienda serán lacadas en blanco. Climatización con bomba frio/calor. Garaje y trastero opcionales por 35.000€. Honorarios de Agencia incluidos. EL COMPRADOR NO PAGA HONORARIOS. En cumplimiento del decreto de la Junta de Andalucía 218-2005 del 11 de octubre, se informa a los clientes que los gastos notariales, registrales e ITP/IVA no están incluidos en el precio. Le recordamos que como consumidor tiene derecho a que se le informe y entregue la documentación informativa que corresponda (D. I. A. ).',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': False,
#     'parkingSpacePrice': 35000.0},
#    'priceByArea': 3297.0,
#    'detailedType': {'typology': 'flat', 'subTypology': 'duplex'},
#    'suggestedTexts': {'subtitle': 'Gran Plaza - Marqués de Pickman - Ciudad Jardín, Sevilla',
#     'title': 'Dúplex en calle Padre Pedro Ayala, 12'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'labels': [{'name': 'bright', 'text': 'Luminoso'}],
#    'highlight': {'groupDescription': 'Destacado'},
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104669907',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/93/e3/78/1228006326.jpg',
#    'externalReference': '492-4',
#    'numPhotos': 10,
#    'floor': '2',
#    'price': 440000.0,
#    'priceInfo': {'price': {'amount': 440000.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 129.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'calle Padre Pedro Ayala, 12',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Gran Plaza - Marqués de Pickman - Ciudad Jardín',
#    'latitude': 37.3869415,
#    'longitude': -5.9639483,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/104669907/',
#    'distance': '505',
#    'description': 'Segunda planta exterior, tres dormitorios, dos baños (uno en suite) y terraza en planta ático. Nueva vivienda en construcción con opción de garaje y trasteros ubicada en pleno corazón de Nervión junto a la Cruz del Campo, Luis Montoto, El Corte Inglés, y al Centro Comercial Los Arcos. Entrega prevista para otoño de 2025. El edificio cuenta planta subterránea de aparcamientos y trasteros privados. Destaca su diseño moderno y elegante, con excelentes calidades. Cada vivienda está dotada de un equipamiento moderno, de calidad y tienen incluida la climatización con aerotermia, lo que reduce el consumo de energía, el aislamiento térmico y acústico en su interior, así como la instalación para las telecomunicaciones. Ventanas con doble cristal y con rotura de puente térmico. Puerta de entrada blindada, con cerradura de seguridad. Las puertas de paso en el interior de la vivienda serán lacadas en blanco. Climatización con bomba frio/calor. Garaje y trastero opcionales por 35.000€. Honorarios de Agencia incluidos. EL COMPRADOR NO PAGA HONORARIOS. En cumplimiento del decreto de la Junta de Andalucía 218-2005 del 11 de octubre, se informa a los clientes que los gastos notariales, registrales e ITP/IVA no están incluidos en el precio. Le recordamos que como consumidor tiene derecho a que se le informe y entregue la documentación informativa que corresponda (D. I. A. ).',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': False,
#     'parkingSpacePrice': 35000.0},
#    'priceByArea': 3411.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Gran Plaza - Marqués de Pickman - Ciudad Jardín, Sevilla',
#     'title': 'Piso en calle Padre Pedro Ayala, 12'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False},
#   {'propertyCode': '104660634',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/2e/de/21/1227690819.jpg',
#    'externalReference': '492-1',
#    'numPhotos': 10,
#    'floor': 'en',
#    'price': 435000.0,
#    'priceInfo': {'price': {'amount': 435000.0}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 137.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'calle Padre Pedro Ayala, 12',
#    'province': 'Sevilla',
#    'municipality': 'Sevilla',
#    'district': 'Nervión',
#    'country': 'es',
#    'neighborhood': 'Gran Plaza - Marqués de Pickman - Ciudad Jardín',
#    'latitude': 37.3869415,
#    'longitude': -5.9639483,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/104660634/',
#    'distance': '505',
#    'description': 'Entreplanta exterior, tres dormitorios, un estudio, dos baños (uno en suite) y dos terrazas/patios. Nueva vivienda en construcción con opción de garaje y trasteros ubicada en pleno corazón de Nervión junto a la Cruz del Campo, Luis Montoto, El Corte Inglés, y al Centro Comercial Los Arcos. Entrega prevista para otoño de 2025. El edificio cuenta planta subterránea de aparcamientos y trasteros privados. Destaca su diseño moderno y elegante, con excelentes calidades. Cada vivienda está dotada de un equipamiento moderno, de calidad y tienen incluida la climatización con aerotermia, lo que reduce el consumo de energía, el aislamiento térmico y acústico en su interior, así como la instalación para las telecomunicaciones. Ventanas con doble cristal y con rotura de puente térmico. Puerta de entrada blindada, con cerradura de seguridad. Las puertas de paso en el interior de la vivienda serán lacadas en blanco. Climatización con bomba frio/calor. Garaje y trastero opcionales por 35.000€. Honorarios de Agencia incluidos. EL COMPRADOR NO PAGA HONORARIOS. En cumplimiento del decreto de la Junta de Andalucía 218-2005 del 11 de octubre, se informa a los clientes que los gastos notariales, registrales e ITP/IVA no están incluidos en el precio. Le recordamos que como consumidor tiene derecho a que se le informe y entregue la documentación informativa que corresponda (D. I. A. ).',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': False,
#     'parkingSpacePrice': 35000.0},
#    'priceByArea': 3175.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Gran Plaza - Marqués de Pickman - Ciudad Jardín, Sevilla',
#     'title': 'Piso en calle Padre Pedro Ayala, 12'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'hasStaging': False,
#    'topNewDevelopment': False,
#    'topPlus': False}],
#  'total': 10143,
#  'totalPages': 203,
#  'actualPage': 1,
#  'itemsPerPage': 50,
#  'numPaginations': 0,
#  'summary': ['Comprar',
#   'Viviendas',
#   'Gran Plaza - Marqués de Pickman - Ciudad Jardín',
#   'Todos los precios',
#   'Todos los tamaños'],
#  'alertName': 'Viviendas en Gran Plaza - Marqués de Pickman - Ciudad Jardín',
#  'totalAppliedFilters': 0,
#  'upperRangePosition': 50,
#  'paginable': True,
#  'lowerRangePosition': 0}

# %%
total_pages = results['totalPages']
total_pages
# Out:
# 203

# %%
def results_to_df(results):
    '''
    This function will save the json results as a dataframe and return the resulting dataframe
    '''
    df = pd.DataFrame.from_dict(results['elementList'])

    return df

# %%
def concat_df(df, df_tot):
    '''
    This function will take the main dataframe (df_tot), and concat it with the given individual dataframe,
    returning the main dataframe
    '''
    df_tot = pd.concat([df_tot,df])

    return df_tot

# %%
# Proceed to save the obtained results as a dataframe
df = results_to_df(results)
df
# Out:
#    propertyCode                                          thumbnail  numPhotos  \
# 0     104379438  https://img3.idealista.com/blur/WEB_LISTING/0/...         14
# 1     104577954  https://img3.idealista.com/blur/WEB_LISTING/0/...         24
# 2     104088494  https://img3.idealista.com/blur/WEB_LISTING/0/...         23
# 3     104583410  https://img3.idealista.com/blur/WEB_LISTING/0/...         25
# 4     103550397  https://img3.idealista.com/blur/WEB_LISTING/0/...         25
# 5     102916820  https://img3.idealista.com/blur/WEB_LISTING/0/...          1
# 6     104717854  https://img3.idealista.com/blur/WEB_LISTING/0/...          8
# 7     104669506  https://img3.idealista.com/blur/WEB_LISTING/0/...         13
# 8     104455365  https://img3.idealista.com/blur/WEB_LISTING/0/...         21
# 9     103772430  https://img3.idealista.com/blur/WEB_LISTING/0/...         24
# 10    103792876  https://img3.idealista.com/blur/WEB_LISTING/0/...         99
# 11    104470837  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 12    104470805  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 13    104470820  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 14    104470836  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 15    104470824  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 16    104470825  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 17    104470822  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 18    104470821  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 19    104718792  https://img3.idealista.com/blur/WEB_LISTING/0/...         16
# 20    104526227  https://img3.idealista.com/blur/WEB_LISTING/0/...         34
# 21    104441577  https://img3.idealista.com/blur/WEB_LISTING/0/...         21
# 22    104506308  https://img3.idealista.com/blur/WEB_LISTING/0/...         22
# 23    104342018  https://img3.idealista.com/blur/WEB_LISTING/0/...         12
# 24    103790202  https://img3.idealista.com/blur/WEB_LISTING/0/...         24
# 25    100370751  https://img3.idealista.com/blur/WEB_LISTING/0/...         30
# 26    104268332  https://img3.idealista.com/blur/WEB_LISTING/0/...         26
# 27    103979844  https://img3.idealista.com/blur/WEB_LISTING/0/...         18
# 28    104343263  https://img3.idealista.com/blur/WEB_LISTING/0/...          9
# 29    104343239  https://img3.idealista.com/blur/WEB_LISTING/0/...          9
# 30    104343194  https://img3.idealista.com/blur/WEB_LISTING/0/...          9
# 31    104343254  https://img3.idealista.com/blur/WEB_LISTING/0/...          9
# 32    104343253  https://img3.idealista.com/blur/WEB_LISTING/0/...          9
# 33    104342866  https://img3.idealista.com/blur/WEB_LISTING/0/...          4
# 34    104342853  https://img3.idealista.com/blur/WEB_LISTING/0/...          4
# 35    104342874  https://img3.idealista.com/blur/WEB_LISTING/0/...          4
# 36    103389259  https://img3.idealista.com/blur/WEB_LISTING/0/...         11
# 37     92667819  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 38    104389177  https://img3.idealista.com/blur/WEB_LISTING/0/...         23
# 39    104091571  https://img3.idealista.com/blur/WEB_LISTING/0/...         34
# 40    103930456  https://img3.idealista.com/blur/WEB_LISTING/0/...         31
# 41    103925012  https://img3.idealista.com/blur/WEB_LISTING/0/...         16
# 42    104358396  https://img3.idealista.com/blur/WEB_LISTING/0/...         14
# 43    104358379  https://img3.idealista.com/blur/WEB_LISTING/0/...         14
# 44    103912731  https://img3.idealista.com/blur/WEB_LISTING/0/...         23
# 45    103619303  https://img3.idealista.com/blur/WEB_LISTING/0/...         82
# 46    104010645  https://img3.idealista.com/blur/WEB_LISTING/0/...         35
# 47    104670035  https://img3.idealista.com/blur/WEB_LISTING/0/...         10
# 48    104669907  https://img3.idealista.com/blur/WEB_LISTING/0/...         10
# 49    104660634  https://img3.idealista.com/blur/WEB_LISTING/0/...         10
#
#    floor     price                                          priceInfo  \
# 0      1  114000.0  {'price': {'amount': 114000.0, 'priceDropInfo'...
# 1      4   95000.0                     {'price': {'amount': 95000.0}}
# 2     12  187000.0                    {'price': {'amount': 187000.0}}
# 3      1   99995.0                     {'price': {'amount': 99995.0}}
# 4      2  270000.0                    {'price': {'amount': 270000.0}}
# 5      3   44900.0                     {'price': {'amount': 44900.0}}
# 6     en   95000.0                     {'price': {'amount': 95000.0}}
# 7      3  128000.0                    {'price': {'amount': 128000.0}}
# 8      2  107000.0                    {'price': {'amount': 107000.0}}
# 9      1  248000.0                    {'price': {'amount': 248000.0}}
# 10   NaN  710000.0                    {'price': {'amount': 710000.0}}
# 11    12  396000.0                    {'price': {'amount': 396000.0}}
# 12   NaN  341500.0                    {'price': {'amount': 341500.0}}
# 13   NaN  418000.0                    {'price': {'amount': 418000.0}}
# 14    10  415000.0                    {'price': {'amount': 415000.0}}
# 15   NaN  397500.0                    {'price': {'amount': 397500.0}}
# 16   NaN  453500.0                    {'price': {'amount': 453500.0}}
# 17   NaN  439500.0                    {'price': {'amount': 439500.0}}
# 18   NaN  444500.0                    {'price': {'amount': 444500.0}}
# 19     2  230000.0                    {'price': {'amount': 230000.0}}
# 20     1  120000.0                    {'price': {'amount': 120000.0}}
# 21    bj  126000.0  {'price': {'amount': 126000.0, 'priceDropInfo'...
# 22     2   99995.0                     {'price': {'amount': 99995.0}}
# 23    12  187000.0                    {'price': {'amount': 187000.0}}
# 24    bj  239000.0  {'price': {'amount': 239000.0, 'priceDropInfo'...
# 25   NaN  365000.0                    {'price': {'amount': 365000.0}}
# 26     2  495000.0                    {'price': {'amount': 495000.0}}
# 27    10  139900.0                    {'price': {'amount': 139900.0}}
# 28     1  285000.0                    {'price': {'amount': 285000.0}}
# 29     1  272000.0                    {'price': {'amount': 272000.0}}
# 30     2  395000.0                    {'price': {'amount': 395000.0}}
# 31     3  385000.0                    {'price': {'amount': 385000.0}}
# 32     1  440000.0                    {'price': {'amount': 440000.0}}
# 33     1  450000.0                    {'price': {'amount': 450000.0}}
# 34     2  380000.0                    {'price': {'amount': 380000.0}}
# 35     1  280000.0                    {'price': {'amount': 280000.0}}
# 36     2  220000.0                    {'price': {'amount': 220000.0}}
# 37     2  306000.0                    {'price': {'amount': 306000.0}}
# 38    bj  126000.0  {'price': {'amount': 126000.0, 'priceDropInfo'...
# 39     2  159900.0                    {'price': {'amount': 159900.0}}
# 40   NaN  480000.0                    {'price': {'amount': 480000.0}}
# 41    bj  349684.0                    {'price': {'amount': 349684.0}}
# 42     3  349684.0                    {'price': {'amount': 349684.0}}
# 43     1  349684.0                    {'price': {'amount': 349684.0}}
# 44     2  270000.0  {'price': {'amount': 270000.0, 'priceDropInfo'...
# 45     2  270000.0                    {'price': {'amount': 270000.0}}
# 46     5  249990.0                    {'price': {'amount': 249990.0}}
# 47     3  455000.0                    {'price': {'amount': 455000.0}}
# 48     2  440000.0                    {'price': {'amount': 440000.0}}
# 49    en  435000.0                    {'price': {'amount': 435000.0}}
#
#    propertyType operation   size exterior  ...  has3DTour  has360 hasStaging  \
# 0          flat      sale   90.0     True  ...      False   False      False
# 1          flat      sale   67.0     True  ...      False   False      False
# 2          flat      sale  125.0     True  ...      False   False      False
# 3          flat      sale   53.0     True  ...      False   False      False
# 4          flat      sale   91.0      NaN  ...      False    True      False
# 5          flat      sale   54.0      NaN  ...      False   False      False
# 6          flat      sale   65.0     True  ...      False   False      False
# 7          flat      sale   77.0     True  ...      False   False      False
# 8          flat      sale   75.0     True  ...      False   False      False
# 9          flat      sale   67.0     True  ...      False   False      False
# 10       chalet      sale  207.0      NaN  ...      False    True      False
# 11         flat      sale  124.0      NaN  ...      False   False      False
# 12         flat      sale  112.0      NaN  ...      False   False      False
# 13         flat      sale  140.0      NaN  ...      False   False      False
# 14         flat      sale  136.0      NaN  ...      False   False      False
# 15         flat      sale  136.0      NaN  ...      False   False      False
# 16         flat      sale  148.0      NaN  ...      False   False      False
# 17         flat      sale  148.0      NaN  ...      False   False      False
# 18         flat      sale  147.0      NaN  ...      False   False      False
# 19         flat      sale   84.0     True  ...      False   False      False
# 20         flat      sale   57.0     True  ...      False   False      False
# 21         flat      sale   60.0     True  ...      False   False      False
# 22         flat      sale   54.0     True  ...      False   False      False
# 23         flat      sale  125.0     True  ...      False   False      False
# 24         flat      sale   97.0     True  ...      False   False      False
# 25       chalet      sale  165.0      NaN  ...       True   False      False
# 26         flat      sale  128.0     True  ...      False   False      False
# 27         flat      sale   95.0     True  ...      False   False      False
# 28         flat      sale   76.0     True  ...      False   False      False
# 29         flat      sale   75.0     True  ...      False   False      False
# 30         flat      sale  103.0     True  ...      False   False      False
# 31         flat      sale  104.0     True  ...      False   False      False
# 32         flat      sale  122.0     True  ...      False   False      False
# 33         flat      sale  123.0     True  ...      False   False      False
# 34         flat      sale  101.0     True  ...      False   False      False
# 35         flat      sale   76.0     True  ...      False   False      False
# 36         flat      sale  105.0     True  ...      False   False      False
# 37         flat      sale   83.0    False  ...      False   False      False
# 38         flat      sale   60.0     True  ...      False   False      False
# 39         flat      sale   61.0     True  ...      False   False      False
# 40       chalet      sale  184.0      NaN  ...      False   False      False
# 41         flat      sale  120.0     True  ...      False   False      False
# 42       duplex      sale  138.0     True  ...      False   False      False
# 43         flat      sale  132.0     True  ...      False   False      False
# 44         flat      sale   96.0     True  ...      False   False      False
# 45         flat      sale   96.0     True  ...      False   False      False
# 46         flat      sale  163.0     True  ...      False   False      False
# 47       duplex      sale  138.0     True  ...      False   False      False
# 48         flat      sale  129.0     True  ...      False   False      False
# 49         flat      sale  137.0     True  ...      False   False      False
#
#    topNewDevelopment topPlus                          highlight  \
# 0              False   False                                NaN
# 1              False   False  {'groupDescription': 'Destacado'}
# 2              False   False                                NaN
# 3              False   False        {'groupDescription': 'Top'}
# 4              False   False  {'groupDescription': 'Destacado'}
# 5              False   False                                NaN
# 6              False   False                                NaN
# 7              False   False  {'groupDescription': 'Destacado'}
# 8              False   False                                NaN
# 9              False   False  {'groupDescription': 'Destacado'}
# 10             False   False        {'groupDescription': 'Top'}
# 11             False   False        {'groupDescription': 'Top'}
# 12             False   False        {'groupDescription': 'Top'}
# 13             False   False        {'groupDescription': 'Top'}
# 14             False   False                                NaN
# 15             False   False                                NaN
# 16             False   False                                NaN
# 17             False   False                                NaN
# 18             False   False                                NaN
# 19             False   False                                NaN
# 20             False   False                                NaN
# 21             False   False  {'groupDescription': 'Destacado'}
# 22             False   False        {'groupDescription': 'Top'}
# 23             False   False                                NaN
# 24             False   False  {'groupDescription': 'Destacado'}
# 25             False   False  {'groupDescription': 'Destacado'}
# 26             False   False                                NaN
# 27             False   False        {'groupDescription': 'Top'}
# 28             False   False                                NaN
# 29             False   False                                NaN
# 30             False   False                                NaN
# 31             False   False                                NaN
# 32             False   False                                NaN
# 33             False   False                                NaN
# 34             False   False                                NaN
# 35             False   False                                NaN
# 36             False   False                                NaN
# 37             False   False  {'groupDescription': 'Destacado'}
# 38             False   False  {'groupDescription': 'Destacado'}
# 39             False   False                                NaN
# 40             False   False  {'groupDescription': 'Destacado'}
# 41             False   False                                NaN
# 42             False   False                                NaN
# 43             False   False                                NaN
# 44             False   False                                NaN
# 45             False   False                                NaN
# 46             False   False  {'groupDescription': 'Destacado'}
# 47             False   False  {'groupDescription': 'Destacado'}
# 48             False   False                                NaN
# 49             False   False                                NaN
#
#    externalReference                                       parkingSpace  \
# 0                NaN                                                NaN
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3          V-SPA-513                                                NaN
# 4      CAN0000197397                                                NaN
# 5      CS-19198-0001                                                NaN
# 6          San Pablo                                                NaN
# 7       manuel-22041                                                NaN
# 8                NaN                                                NaN
# 9          1B4101168  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 10               NaN  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 11         100096672                                                NaN
# 12         100096584                                                NaN
# 13         100096588                                                NaN
# 14         100096662                                                NaN
# 15         100096646                                                NaN
# 16         100096653                                                NaN
# 17         100096637                                                NaN
# 18         100096593                                                NaN
# 19               NaN                                                NaN
# 20          17008131                                                NaN
# 21         LCSE29510                                                NaN
# 22         V-SPA-512                                                NaN
# 23           PIS_166                                                NaN
# 24           NERVION  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 25          SJ182249                                                NaN
# 26               NaN  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 27         V-SPC-502                                                NaN
# 28   VIDE10617870011                                                NaN
# 29   VIDE10617870010                                                NaN
# 30   VIDE10617870020                                                NaN
# 31   VIDE10617870029                                                NaN
# 32   VIDE10617870015                                                NaN
# 33   VIDE07779100002                                                NaN
# 34   VIDE07779100007                                                NaN
# 35   VIDE07779100004                                                NaN
# 36           PIS_162                                                NaN
# 37          031506ON  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 38               NaN                                                NaN
# 39               NaN                                                NaN
# 40               NaN                                                NaN
# 41              Bajo                                                NaN
# 42               NaN                                                NaN
# 43               NaN                                                NaN
# 44          AV.AND20                                                NaN
# 45               NaN                                                NaN
# 46               NaN                                                NaN
# 47             492-6  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 48             492-4  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 49             492-1  {'hasParkingSpace': True, 'isParkingSpaceInclu...
#
#     newDevelopmentFinished                                    labels
# 0                      NaN                                       NaN
# 1                      NaN                                       NaN
# 2                      NaN                                       NaN
# 3                      NaN                                       NaN
# 4                      NaN                                       NaN
# 5                      NaN                                       NaN
# 6                      NaN                                       NaN
# 7                      NaN                                       NaN
# 8                      NaN                                       NaN
# 9                      NaN                                       NaN
# 10                     NaN                                       NaN
# 11                   False                                       NaN
# 12                   False                                       NaN
# 13                   False                                       NaN
# 14                   False                                       NaN
# 15                   False                                       NaN
# 16                   False                                       NaN
# 17                   False                                       NaN
# 18                   False                                       NaN
# 19                     NaN                                       NaN
# 20                     NaN                                       NaN
# 21                     NaN                                       NaN
# 22                     NaN                                       NaN
# 23                     NaN                                       NaN
# 24                     NaN                                       NaN
# 25                     NaN                                       NaN
# 26                     NaN                                       NaN
# 27                     NaN                                       NaN
# 28                   False                                       NaN
# 29                   False                                       NaN
# 30                   False                                       NaN
# 31                   False                                       NaN
# 32                   False                                       NaN
# 33                   False                                       NaN
# 34                   False                                       NaN
# 35                   False                                       NaN
# 36                     NaN                                       NaN
# 37                     NaN                                       NaN
# 38                     NaN                                       NaN
# 39                     NaN                                       NaN
# 40                     NaN                                       NaN
# 41                   False                                       NaN
# 42                   False                                       NaN
# 43                   False                                       NaN
# 44                     NaN                                       NaN
# 45                     NaN                                       NaN
# 46                     NaN                                       NaN
# 47                     NaN  [{'name': 'bright', 'text': 'Luminoso'}]
# 48                     NaN                                       NaN
# 49                     NaN                                       NaN
#
# [50 rows x 42 columns]

# %%
# Since we still don't have a main dataframe where we can store all the data, we will create an empty dataframe
df_tot = pd.DataFrame()
df_tot = concat_df(df, df_tot)

# %%
df_tot
# Out:
#    propertyCode                                          thumbnail  numPhotos  \
# 0     104379438  https://img3.idealista.com/blur/WEB_LISTING/0/...         14
# 1     104577954  https://img3.idealista.com/blur/WEB_LISTING/0/...         24
# 2     104088494  https://img3.idealista.com/blur/WEB_LISTING/0/...         23
# 3     104583410  https://img3.idealista.com/blur/WEB_LISTING/0/...         25
# 4     103550397  https://img3.idealista.com/blur/WEB_LISTING/0/...         25
# 5     102916820  https://img3.idealista.com/blur/WEB_LISTING/0/...          1
# 6     104717854  https://img3.idealista.com/blur/WEB_LISTING/0/...          8
# 7     104669506  https://img3.idealista.com/blur/WEB_LISTING/0/...         13
# 8     104455365  https://img3.idealista.com/blur/WEB_LISTING/0/...         21
# 9     103772430  https://img3.idealista.com/blur/WEB_LISTING/0/...         24
# 10    103792876  https://img3.idealista.com/blur/WEB_LISTING/0/...         99
# 11    104470837  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 12    104470805  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 13    104470820  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 14    104470836  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 15    104470824  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 16    104470825  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 17    104470822  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 18    104470821  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 19    104718792  https://img3.idealista.com/blur/WEB_LISTING/0/...         16
# 20    104526227  https://img3.idealista.com/blur/WEB_LISTING/0/...         34
# 21    104441577  https://img3.idealista.com/blur/WEB_LISTING/0/...         21
# 22    104506308  https://img3.idealista.com/blur/WEB_LISTING/0/...         22
# 23    104342018  https://img3.idealista.com/blur/WEB_LISTING/0/...         12
# 24    103790202  https://img3.idealista.com/blur/WEB_LISTING/0/...         24
# 25    100370751  https://img3.idealista.com/blur/WEB_LISTING/0/...         30
# 26    104268332  https://img3.idealista.com/blur/WEB_LISTING/0/...         26
# 27    103979844  https://img3.idealista.com/blur/WEB_LISTING/0/...         18
# 28    104343263  https://img3.idealista.com/blur/WEB_LISTING/0/...          9
# 29    104343239  https://img3.idealista.com/blur/WEB_LISTING/0/...          9
# 30    104343194  https://img3.idealista.com/blur/WEB_LISTING/0/...          9
# 31    104343254  https://img3.idealista.com/blur/WEB_LISTING/0/...          9
# 32    104343253  https://img3.idealista.com/blur/WEB_LISTING/0/...          9
# 33    104342866  https://img3.idealista.com/blur/WEB_LISTING/0/...          4
# 34    104342853  https://img3.idealista.com/blur/WEB_LISTING/0/...          4
# 35    104342874  https://img3.idealista.com/blur/WEB_LISTING/0/...          4
# 36    103389259  https://img3.idealista.com/blur/WEB_LISTING/0/...         11
# 37     92667819  https://img3.idealista.com/blur/WEB_LISTING/0/...         20
# 38    104389177  https://img3.idealista.com/blur/WEB_LISTING/0/...         23
# 39    104091571  https://img3.idealista.com/blur/WEB_LISTING/0/...         34
# 40    103930456  https://img3.idealista.com/blur/WEB_LISTING/0/...         31
# 41    103925012  https://img3.idealista.com/blur/WEB_LISTING/0/...         16
# 42    104358396  https://img3.idealista.com/blur/WEB_LISTING/0/...         14
# 43    104358379  https://img3.idealista.com/blur/WEB_LISTING/0/...         14
# 44    103912731  https://img3.idealista.com/blur/WEB_LISTING/0/...         23
# 45    103619303  https://img3.idealista.com/blur/WEB_LISTING/0/...         82
# 46    104010645  https://img3.idealista.com/blur/WEB_LISTING/0/...         35
# 47    104670035  https://img3.idealista.com/blur/WEB_LISTING/0/...         10
# 48    104669907  https://img3.idealista.com/blur/WEB_LISTING/0/...         10
# 49    104660634  https://img3.idealista.com/blur/WEB_LISTING/0/...         10
#
#    floor     price                                          priceInfo  \
# 0      1  114000.0  {'price': {'amount': 114000.0, 'priceDropInfo'...
# 1      4   95000.0                     {'price': {'amount': 95000.0}}
# 2     12  187000.0                    {'price': {'amount': 187000.0}}
# 3      1   99995.0                     {'price': {'amount': 99995.0}}
# 4      2  270000.0                    {'price': {'amount': 270000.0}}
# 5      3   44900.0                     {'price': {'amount': 44900.0}}
# 6     en   95000.0                     {'price': {'amount': 95000.0}}
# 7      3  128000.0                    {'price': {'amount': 128000.0}}
# 8      2  107000.0                    {'price': {'amount': 107000.0}}
# 9      1  248000.0                    {'price': {'amount': 248000.0}}
# 10   NaN  710000.0                    {'price': {'amount': 710000.0}}
# 11    12  396000.0                    {'price': {'amount': 396000.0}}
# 12   NaN  341500.0                    {'price': {'amount': 341500.0}}
# 13   NaN  418000.0                    {'price': {'amount': 418000.0}}
# 14    10  415000.0                    {'price': {'amount': 415000.0}}
# 15   NaN  397500.0                    {'price': {'amount': 397500.0}}
# 16   NaN  453500.0                    {'price': {'amount': 453500.0}}
# 17   NaN  439500.0                    {'price': {'amount': 439500.0}}
# 18   NaN  444500.0                    {'price': {'amount': 444500.0}}
# 19     2  230000.0                    {'price': {'amount': 230000.0}}
# 20     1  120000.0                    {'price': {'amount': 120000.0}}
# 21    bj  126000.0  {'price': {'amount': 126000.0, 'priceDropInfo'...
# 22     2   99995.0                     {'price': {'amount': 99995.0}}
# 23    12  187000.0                    {'price': {'amount': 187000.0}}
# 24    bj  239000.0  {'price': {'amount': 239000.0, 'priceDropInfo'...
# 25   NaN  365000.0                    {'price': {'amount': 365000.0}}
# 26     2  495000.0                    {'price': {'amount': 495000.0}}
# 27    10  139900.0                    {'price': {'amount': 139900.0}}
# 28     1  285000.0                    {'price': {'amount': 285000.0}}
# 29     1  272000.0                    {'price': {'amount': 272000.0}}
# 30     2  395000.0                    {'price': {'amount': 395000.0}}
# 31     3  385000.0                    {'price': {'amount': 385000.0}}
# 32     1  440000.0                    {'price': {'amount': 440000.0}}
# 33     1  450000.0                    {'price': {'amount': 450000.0}}
# 34     2  380000.0                    {'price': {'amount': 380000.0}}
# 35     1  280000.0                    {'price': {'amount': 280000.0}}
# 36     2  220000.0                    {'price': {'amount': 220000.0}}
# 37     2  306000.0                    {'price': {'amount': 306000.0}}
# 38    bj  126000.0  {'price': {'amount': 126000.0, 'priceDropInfo'...
# 39     2  159900.0                    {'price': {'amount': 159900.0}}
# 40   NaN  480000.0                    {'price': {'amount': 480000.0}}
# 41    bj  349684.0                    {'price': {'amount': 349684.0}}
# 42     3  349684.0                    {'price': {'amount': 349684.0}}
# 43     1  349684.0                    {'price': {'amount': 349684.0}}
# 44     2  270000.0  {'price': {'amount': 270000.0, 'priceDropInfo'...
# 45     2  270000.0                    {'price': {'amount': 270000.0}}
# 46     5  249990.0                    {'price': {'amount': 249990.0}}
# 47     3  455000.0                    {'price': {'amount': 455000.0}}
# 48     2  440000.0                    {'price': {'amount': 440000.0}}
# 49    en  435000.0                    {'price': {'amount': 435000.0}}
#
#    propertyType operation   size exterior  ...  has3DTour  has360 hasStaging  \
# 0          flat      sale   90.0     True  ...      False   False      False
# 1          flat      sale   67.0     True  ...      False   False      False
# 2          flat      sale  125.0     True  ...      False   False      False
# 3          flat      sale   53.0     True  ...      False   False      False
# 4          flat      sale   91.0      NaN  ...      False    True      False
# 5          flat      sale   54.0      NaN  ...      False   False      False
# 6          flat      sale   65.0     True  ...      False   False      False
# 7          flat      sale   77.0     True  ...      False   False      False
# 8          flat      sale   75.0     True  ...      False   False      False
# 9          flat      sale   67.0     True  ...      False   False      False
# 10       chalet      sale  207.0      NaN  ...      False    True      False
# 11         flat      sale  124.0      NaN  ...      False   False      False
# 12         flat      sale  112.0      NaN  ...      False   False      False
# 13         flat      sale  140.0      NaN  ...      False   False      False
# 14         flat      sale  136.0      NaN  ...      False   False      False
# 15         flat      sale  136.0      NaN  ...      False   False      False
# 16         flat      sale  148.0      NaN  ...      False   False      False
# 17         flat      sale  148.0      NaN  ...      False   False      False
# 18         flat      sale  147.0      NaN  ...      False   False      False
# 19         flat      sale   84.0     True  ...      False   False      False
# 20         flat      sale   57.0     True  ...      False   False      False
# 21         flat      sale   60.0     True  ...      False   False      False
# 22         flat      sale   54.0     True  ...      False   False      False
# 23         flat      sale  125.0     True  ...      False   False      False
# 24         flat      sale   97.0     True  ...      False   False      False
# 25       chalet      sale  165.0      NaN  ...       True   False      False
# 26         flat      sale  128.0     True  ...      False   False      False
# 27         flat      sale   95.0     True  ...      False   False      False
# 28         flat      sale   76.0     True  ...      False   False      False
# 29         flat      sale   75.0     True  ...      False   False      False
# 30         flat      sale  103.0     True  ...      False   False      False
# 31         flat      sale  104.0     True  ...      False   False      False
# 32         flat      sale  122.0     True  ...      False   False      False
# 33         flat      sale  123.0     True  ...      False   False      False
# 34         flat      sale  101.0     True  ...      False   False      False
# 35         flat      sale   76.0     True  ...      False   False      False
# 36         flat      sale  105.0     True  ...      False   False      False
# 37         flat      sale   83.0    False  ...      False   False      False
# 38         flat      sale   60.0     True  ...      False   False      False
# 39         flat      sale   61.0     True  ...      False   False      False
# 40       chalet      sale  184.0      NaN  ...      False   False      False
# 41         flat      sale  120.0     True  ...      False   False      False
# 42       duplex      sale  138.0     True  ...      False   False      False
# 43         flat      sale  132.0     True  ...      False   False      False
# 44         flat      sale   96.0     True  ...      False   False      False
# 45         flat      sale   96.0     True  ...      False   False      False
# 46         flat      sale  163.0     True  ...      False   False      False
# 47       duplex      sale  138.0     True  ...      False   False      False
# 48         flat      sale  129.0     True  ...      False   False      False
# 49         flat      sale  137.0     True  ...      False   False      False
#
#    topNewDevelopment topPlus                          highlight  \
# 0              False   False                                NaN
# 1              False   False  {'groupDescription': 'Destacado'}
# 2              False   False                                NaN
# 3              False   False        {'groupDescription': 'Top'}
# 4              False   False  {'groupDescription': 'Destacado'}
# 5              False   False                                NaN
# 6              False   False                                NaN
# 7              False   False  {'groupDescription': 'Destacado'}
# 8              False   False                                NaN
# 9              False   False  {'groupDescription': 'Destacado'}
# 10             False   False        {'groupDescription': 'Top'}
# 11             False   False        {'groupDescription': 'Top'}
# 12             False   False        {'groupDescription': 'Top'}
# 13             False   False        {'groupDescription': 'Top'}
# 14             False   False                                NaN
# 15             False   False                                NaN
# 16             False   False                                NaN
# 17             False   False                                NaN
# 18             False   False                                NaN
# 19             False   False                                NaN
# 20             False   False                                NaN
# 21             False   False  {'groupDescription': 'Destacado'}
# 22             False   False        {'groupDescription': 'Top'}
# 23             False   False                                NaN
# 24             False   False  {'groupDescription': 'Destacado'}
# 25             False   False  {'groupDescription': 'Destacado'}
# 26             False   False                                NaN
# 27             False   False        {'groupDescription': 'Top'}
# 28             False   False                                NaN
# 29             False   False                                NaN
# 30             False   False                                NaN
# 31             False   False                                NaN
# 32             False   False                                NaN
# 33             False   False                                NaN
# 34             False   False                                NaN
# 35             False   False                                NaN
# 36             False   False                                NaN
# 37             False   False  {'groupDescription': 'Destacado'}
# 38             False   False  {'groupDescription': 'Destacado'}
# 39             False   False                                NaN
# 40             False   False  {'groupDescription': 'Destacado'}
# 41             False   False                                NaN
# 42             False   False                                NaN
# 43             False   False                                NaN
# 44             False   False                                NaN
# 45             False   False                                NaN
# 46             False   False  {'groupDescription': 'Destacado'}
# 47             False   False  {'groupDescription': 'Destacado'}
# 48             False   False                                NaN
# 49             False   False                                NaN
#
#    externalReference                                       parkingSpace  \
# 0                NaN                                                NaN
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3          V-SPA-513                                                NaN
# 4      CAN0000197397                                                NaN
# 5      CS-19198-0001                                                NaN
# 6          San Pablo                                                NaN
# 7       manuel-22041                                                NaN
# 8                NaN                                                NaN
# 9          1B4101168  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 10               NaN  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 11         100096672                                                NaN
# 12         100096584                                                NaN
# 13         100096588                                                NaN
# 14         100096662                                                NaN
# 15         100096646                                                NaN
# 16         100096653                                                NaN
# 17         100096637                                                NaN
# 18         100096593                                                NaN
# 19               NaN                                                NaN
# 20          17008131                                                NaN
# 21         LCSE29510                                                NaN
# 22         V-SPA-512                                                NaN
# 23           PIS_166                                                NaN
# 24           NERVION  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 25          SJ182249                                                NaN
# 26               NaN  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 27         V-SPC-502                                                NaN
# 28   VIDE10617870011                                                NaN
# 29   VIDE10617870010                                                NaN
# 30   VIDE10617870020                                                NaN
# 31   VIDE10617870029                                                NaN
# 32   VIDE10617870015                                                NaN
# 33   VIDE07779100002                                                NaN
# 34   VIDE07779100007                                                NaN
# 35   VIDE07779100004                                                NaN
# 36           PIS_162                                                NaN
# 37          031506ON  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 38               NaN                                                NaN
# 39               NaN                                                NaN
# 40               NaN                                                NaN
# 41              Bajo                                                NaN
# 42               NaN                                                NaN
# 43               NaN                                                NaN
# 44          AV.AND20                                                NaN
# 45               NaN                                                NaN
# 46               NaN                                                NaN
# 47             492-6  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 48             492-4  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 49             492-1  {'hasParkingSpace': True, 'isParkingSpaceInclu...
#
#     newDevelopmentFinished                                    labels
# 0                      NaN                                       NaN
# 1                      NaN                                       NaN
# 2                      NaN                                       NaN
# 3                      NaN                                       NaN
# 4                      NaN                                       NaN
# 5                      NaN                                       NaN
# 6                      NaN                                       NaN
# 7                      NaN                                       NaN
# 8                      NaN                                       NaN
# 9                      NaN                                       NaN
# 10                     NaN                                       NaN
# 11                   False                                       NaN
# 12                   False                                       NaN
# 13                   False                                       NaN
# 14                   False                                       NaN
# 15                   False                                       NaN
# 16                   False                                       NaN
# 17                   False                                       NaN
# 18                   False                                       NaN
# 19                     NaN                                       NaN
# 20                     NaN                                       NaN
# 21                     NaN                                       NaN
# 22                     NaN                                       NaN
# 23                     NaN                                       NaN
# 24                     NaN                                       NaN
# 25                     NaN                                       NaN
# 26                     NaN                                       NaN
# 27                     NaN                                       NaN
# 28                   False                                       NaN
# 29                   False                                       NaN
# 30                   False                                       NaN
# 31                   False                                       NaN
# 32                   False                                       NaN
# 33                   False                                       NaN
# 34                   False                                       NaN
# 35                   False                                       NaN
# 36                     NaN                                       NaN
# 37                     NaN                                       NaN
# 38                     NaN                                       NaN
# 39                     NaN                                       NaN
# 40                     NaN                                       NaN
# 41                   False                                       NaN
# 42                   False                                       NaN
# 43                   False                                       NaN
# 44                     NaN                                       NaN
# 45                     NaN                                       NaN
# 46                     NaN                                       NaN
# 47                     NaN  [{'name': 'bright', 'text': 'Luminoso'}]
# 48                     NaN                                       NaN
# 49                     NaN                                       NaN
#
# [50 rows x 42 columns]

# %%
# This will loop over all the pages in the search results. It start from 2, because we've already gotten the first page
for i in range(2, total_pages + 1):

    url_page = url %(i)   # Add the pagination to the url
    results = search_api(url_page)   # Get the search results
    df = results_to_df(results)   # Save the results as a dataframe
    df_tot = concat_df(df, df_tot)   # Concat the results to the main dataframe
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-97-96e0b4308de1> in <cell line: 2>()
#       3
#       4     url_page = url %(i)   # Add the pagination to the url
# ----> 5     results = search_api(url_page)   # Get the search results
#       6     df = results_to_df(results)   # Save the results as a dataframe
#       7     df_tot = concat_df(df, df_tot)   # Concat the results to the main dataframe
#
# <ipython-input-87-c17fe859fae8> in search_api(url)
#      10     content = rq.post(url, headers = headers)   # Return the content from the request
#      11
# ---> 12     result = json.loads(content.text)   # Transform the result as a json file
#      13
#      14     return result
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/lib/python3.10/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df_tot
# Out:
#    propertyCode                                          thumbnail  numPhotos  \
# 0     104379438  https://img3.idealista.com/blur/WEB_LISTING/0/...         14
# 1     104577954  https://img3.idealista.com/blur/WEB_LISTING/0/...         24
# 2     104088494  https://img3.idealista.com/blur/WEB_LISTING/0/...         23
# 3     104583410  https://img3.idealista.com/blur/WEB_LISTING/0/...         25
# 4     103550397  https://img3.idealista.com/blur/WEB_LISTING/0/...         25
# ..          ...                                                ...        ...
# 45    102063111  https://img3.idealista.com/blur/WEB_LISTING/0/...         32
# 46    104500350  https://img3.idealista.com/blur/WEB_LISTING/0/...         29
# 47    104603468  https://img3.idealista.com/blur/WEB_LISTING/0/...         38
# 48    104358287  https://img3.idealista.com/blur/WEB_LISTING/0/...         10
# 49    104707528  https://img3.idealista.com/blur/WEB_LISTING/0/...         16
#
#    floor     price                                          priceInfo  \
# 0      1  114000.0  {'price': {'amount': 114000.0, 'priceDropInfo'...
# 1      4   95000.0                     {'price': {'amount': 95000.0}}
# 2     12  187000.0                    {'price': {'amount': 187000.0}}
# 3      1   99995.0                     {'price': {'amount': 99995.0}}
# 4      2  270000.0                    {'price': {'amount': 270000.0}}
# ..   ...       ...                                                ...
# 45   NaN  350000.0                    {'price': {'amount': 350000.0}}
# 46   NaN  240000.0                    {'price': {'amount': 240000.0}}
# 47   NaN  125000.0                    {'price': {'amount': 125000.0}}
# 48    bj  146900.0                    {'price': {'amount': 146900.0}}
# 49   NaN  150000.0                    {'price': {'amount': 150000.0}}
#
#     propertyType operation   size exterior  ...  has3DTour  has360 hasStaging  \
# 0           flat      sale   90.0     True  ...      False   False      False
# 1           flat      sale   67.0     True  ...      False   False      False
# 2           flat      sale  125.0     True  ...      False   False      False
# 3           flat      sale   53.0     True  ...      False   False      False
# 4           flat      sale   91.0      NaN  ...      False    True      False
# ..           ...       ...    ...      ...  ...        ...     ...        ...
# 45        chalet      sale  285.0      NaN  ...      False   False      False
# 46        chalet      sale  149.0      NaN  ...      False   False      False
# 47  countryHouse      sale  145.0      NaN  ...      False   False      False
# 48          flat      sale  100.0    False  ...      False   False      False
# 49          flat      sale  130.0     True  ...      False   False      False
#
#    topNewDevelopment topPlus                          highlight  \
# 0              False   False                                NaN
# 1              False   False  {'groupDescription': 'Destacado'}
# 2              False   False                                NaN
# 3              False   False        {'groupDescription': 'Top'}
# 4              False   False  {'groupDescription': 'Destacado'}
# ..               ...     ...                                ...
# 45             False   False  {'groupDescription': 'Destacado'}
# 46             False   False                                NaN
# 47             False   False                                NaN
# 48             False   False  {'groupDescription': 'Destacado'}
# 49             False   False                                NaN
#
#    externalReference                                       parkingSpace  \
# 0                NaN                                                NaN
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3          V-SPA-513                                                NaN
# 4      CAN0000197397                                                NaN
# ..               ...                                                ...
# 45            1949SG  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 46             01468  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 47           CRV-107                                                NaN
# 48        1435-M2387  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 49             22464                                                NaN
#
#     newDevelopmentFinished  labels
# 0                      NaN     NaN
# 1                      NaN     NaN
# 2                      NaN     NaN
# 3                      NaN     NaN
# 4                      NaN     NaN
# ..                     ...     ...
# 45                     NaN     NaN
# 46                     NaN     NaN
# 47                     NaN     NaN
# 48                     NaN     NaN
# 49                     NaN     NaN
#
# [5000 rows x 42 columns]

# %%
# Once we have all our data, we just need to save it as a csv file, we have created the following function for that:
import os

file_name = 'idealistaCompra.csv'

def df_to_csv(df):
    '''
    This function takes a given dataframe and saves it as a CSV file in the same directory as the Colab notebook.
    '''
    file_path = os.path.join(os.getcwd(), file_name)
    df = df.reset_index()   # Reset the index to organize the records
    df.to_csv(file_path, index=False)   # Save it into a CSV
    return file_path

# %%
# Run the function to save the dataframe as a CSV file in the same directory as the Colab notebook
csv_file_path = df_to_csv(df_tot)
print("CSV file saved at:", csv_file_path)
# Out:
# CSV file saved at: /content/idealistaCompra.csv
